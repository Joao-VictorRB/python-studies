# %% [markdown]
# 1. Monte um cadastro simples (nome, idade, cidade, ativo) e imprima uma frase completa.

# %%
nome = "João"
idade = 25
cidade = "São Paulo"
ativo = True

print(f"Nome: {nome}, Idade: {idade}, Cidade: {cidade}, Ativo: {ativo}")

# %% [markdown]
# 2. Troque os valores de duas variaveis (ex: preco_antigo e preco_novo) sem usar variavel auxiliar.

# %%
preco_old = 100.0
preco_new = 80.0

print(f"Preço antigo: {preco_old}, Preço novo: {preco_new}")

preco_old = 10.0
preco_new = 10.0

print(f"Preço antigo: {preco_old}, Preço novo: {preco_new}")

# %% [markdown]
# 3. Use constantes para TAXA_SERVICO e DESCONTO e calcule o valor final de uma conta.

# %%
valor = 50.0
taxa = valor * 0.20

desconto  = valor * 0.15

print(f"Valor: {valor}, Taxa: {taxa}, Desconto: {desconto}")
